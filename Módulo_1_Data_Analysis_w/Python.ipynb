# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-RodrigoPepi/blob/main/M%C3%B3dulo_1_Data_Analysis_w/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Segundo curso de IBM para Ciencia y Analítica de Datos
#
# Rodrigo Pepi Guerra A01382430.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Apuntes
# En general cuando se quieren realizar actividades de ciencia de datos, es conveniente siempre tener en cuenta en primer lugar: lo que se quiere conseguir o lo que se espera obtener de la información a analizar. Posteriormente y una parte esencial de realizar análisis es el conocimiento general de la información o parámetros que se estarán considerando para obtener los resultados deseados. Ya sean estos variables numéricas enteras, variables numéricas continuas o discretas, series temporales o incluso atributos categóricos.
#
# Del mismo modo una de las actividades esenciales realizadas al momento de obtener un mayor conocimiento de los atributos a considerar es su composición, llámese la cantidad de registros nulos, medias, medianas, modas u otro tipo de información descriptiva que pueda ayudarnos a manipular mejor la información en caso de tener que realizar transformaciones o escalamientos de los datos.

# %% [markdown]
# # Librerias
#
# De las librerías más utilizadas para la ciencia de datos, hay 3 principales, 2 de ellas ya las hemos visto en clase (Pandas y Numpy) que son utilizadas principalmente para poder manipular datos estructurados, o manipular información de matrices para realizar operaciones complejas de algebra lineal. Cada una de estas bibliotecas ayuda a reducir el tiempo de procesamiento que necesita la computadora para realizar sus actividades, pues procesar ese tipo de información en un formato que nosotros diseñemos desde cero no será tan eficiente.
#
# La librería Scipy también es esencial en la ciencia de datos, pues las librerías mencionadas; crean en conjunto o componen otras librerías como lo son scikit learn o matplotlib, que tienen dentro de ellas muchos modelos definidos y también diferentes tipos de opciones para graficar y entender mejor los resultados generados.

# %% [markdown]
# # Formulas importantes en Pandas para Dataframes
#
# Con la librería pandas podemos realizar distintas operaciones o procedimientos, como lo sería el estar describiendo su composición, longitud, diferentes datos de estadística descriptiva y manipular a nuestra conveniencia los datos que estaremos utilizando como modificar nombres de las columnas; su orden o el tipo de datos que representa (cambiar algún dato de string a entero o algún otro tipo).
