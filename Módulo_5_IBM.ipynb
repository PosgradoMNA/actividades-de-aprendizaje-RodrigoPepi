# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-RodrigoPepi/blob/main/M%C3%B3dulo_5_IBM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Warehousing

# %% [markdown]
# ETL: extract, transform, and load.
# This technique presents problems when working with very large datasets, scalability is not as easy and this can introduce stability problems to the data warehouse pipeline.

# %% [markdown]
# ELT: It flips on itself but basically it makes the repository where the information is placed to be processed or transformed within it. This is used mostly with raw text files and it allows to transform larger datasets without damaging format.

# %% [markdown]
# #Module 5 Notes

# %% [markdown]
# The Basics And Array Creation
# Create a numpy Array:
#
# A list is a container that allows you to store data with an index.
#
# A numpy array is similar to a list and it usually has a fixed size and type.
#
# Then you can store the values of list in an indexed array, you can access the array information as if it were a list. you must declare:

# %%
import numpy as np
a = np.array([0,1,2,3,4])
a.size # Size of the array
# Out:
# 5

# %%
a = np.array([0,1,2,3,4]) # Dimensions of the Array
a.ndim
# Out:
# 1

# %%
a = np.array([0,1,2,3,4]) # Size of the array in each dimension
a.shape
# Out:
# (5,)

# %%
b=np.array ([3.1,13.8,74.2,6.87,178.3])
type(b) # Check data type
b.dtype
# Out:
# dtype('float64')

# %%
c=np.array([0,1,2,3,4])
c
# Out:
# array([0, 1, 2, 3, 4])

# %%
c[0]=25
c   # Change Value according to index
# Out:
# array([25,  1,  2,  3,  4])

# %%
d = c[1:4] # Assign an array to a variable 
d
# Out:
# array([1, 2, 3])

# %%
c[1:3]=100,25
c
# Out:
# array([  0, 100,  25,   3,   4])

# %% [markdown]
# #Basic Operations are faster in numpy than regular python
#
# Vectors have two components and they can be added to create a new component, being each other the linear combination of each veactor with each other.
#
# How to graph a vectorial graph of added vectors:

# %%
u=[0,1] # Not an efficient way to store data in regular code
v=[0,1]
z=[]
for n, m in zip(u,v):
    z.append(n+m)
    z

# %%
    u =np.array([1,0]) #Doing the same with one line of code
    v=np.array([0,1])
    z = u+v
    z
# Out:
# array([1, 1])

# %%
y = np.array([1,2])     #Performing multiplications
z =2*y
z
# Out:
# array([2, 4])

# %%
u =np.array([1,2]) # Performing Scalar multiplications
v=np.array([2,3])
z=u*v

# %%
u =np.array([1,2]) # Performing Dot Product
v=np.array([3,1])

result=np.dot(u,v)
result
# Out:
# 5

# %%
u = np.array([1,2]) #Broadcasting or adding to all members of the array

z = u + 1
z
# Out:
# array([2, 3])

# %%
a = np.array([1,-1,1,-1]) # perform stratistical operations like mean
mean_a=a.mean()
mean_a
# Out:
# 0.0

# %%
a.max() # return max
# Out:
# 1

# %%
np.pi # litearally PI
x=np.array([0,np.pi/2,np.pi]) # Do trigonometrical Operations in Code
y=np.sin(x)
y
# Out:
# array([0.0000000e+00, 1.0000000e+00, 1.2246468e-16])

# %%
#useful function to plot mathematical functions
np.linspace(-2,2,num=9)
# Out:
# array([-2. , -1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5,  2. ])

# %%
from ast import increment_lineno
import matplotlib.pyplot as plt
x =np.linspace(0,2*np.pi,100)
y=np.sin(x)

# %matplotlib inline
plt.plot(x,y)

# %% [markdown]
# # Numpy 2D Arrays

# %%
# Consider the following list, nested
import numpy as np
import matplotlib.pyplot as plt

a = [[11,12,13],[21,22,23],[31,32,33]]
A =np.array(a)
A
# Out:
# array([[11, 12, 13],
#        [21, 22, 23],
#        [31, 32, 33]])

# %%
A.ndim # This will show the number of axis or dimensions, the nested lists represent an axis with values 1,2,3 and each of them contains the values of their own nested list which represent the next dimension
# Out:
# 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Useful way to see indexing conventions

# %%
A[0:2,2] # Slicing in np arrays is also possible

# %%
# You can add arrays which is identical to matrix addition

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
X = np.array([[1,0],[0,1]])
Y = np.array([[2,1],[1,2]])
Z = X + Y 
Z
# Out:
# array([[3, 1],
#        [1, 3]])

# %%
2*Y # Performing Scalar operation to a matrix is the same as a matrix being multiplied by a vector
# Out:
# array([[4, 2],
#        [2, 4]])

# %%
# Hadamar or point product is the multiplication of the different coeficients in both matrixes by the ones occupying the same position in each matrix
W = X*Y
W
# Out:
# array([[2, 0],
#        [0, 2]])

# %%
# Matrix multiplication must be with matrices which have opposite numbers of rows and columns to be performed, consider: 
D = np.array([[0,1,1],[1,0,1]])
C = np.array([[1,1],[1,1],[-1,1]])
F = np.dot(D,C)
F
# Out:
# array([[0, 2],
#        [0, 2]])

# %% [markdown]
# # API'S
